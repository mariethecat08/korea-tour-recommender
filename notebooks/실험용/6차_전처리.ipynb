# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/sopi0/codes/korea-tour-recommender/data/2024_5차_전처리.csv')

# %%
df.columns
# Out:
# Index(['아이디', '성별', '연령별', '한국 방문횟수(카테고리)', '문1-1. 한국여행 관심 계기_1',
#        '문3-1. 고려한 관광활동_1', '문3-2. 고려한 관광인프라_1',
#        '문10. 1인 1일 지출경비(상하위 1% 대체, 61일 이상 결측)', '문9-3. 총 체재기간_61일 이상 결측',
#        '숙박시설_그룹', '여행동반자_그룹', '방문 지역 수', '식비_비율', '국내 교통비_비율', '체험/활동비_비율',
#        '뷰티/의료비_비율', '여행 서비스비_비율', '숙박비_비율', '쇼핑비_비율', '기타 비용_비율', '여행 패턴'],
#       dtype='object')

# %%
raw = pd.read_csv('C:/Users/sopi0/codes/korea-tour-recommender/data/2024_만족도조사.csv', encoding='cp949')

# %%
raw
# Out:
#        Unnamed: 0    아이디  한국 방문횟수(평균)  한국 방문횟수(카테고리)  한국 방문횟수(재방문)  여행 형태  \
# 0               0     57            5              4           5.0      1
# 1               1     58            4              4           5.0      1
# 2               2     59            3              3           5.0      1
# 3               3     60            1              1           NaN      1
# 4               4     61            5              4           5.0      1
# ...           ...    ...          ...            ...           ...    ...
# 16211       16211  19273            2              2           5.0      1
# 16212       16212  19274            2              2           5.0      1
# 16213       16213  19275            1              1           NaN      1
# 16214       16214  19277            2              2           5.0      1
# 16215       16215  19279            1              1           NaN      1
#
#        문1. 주요 방한 목적  문1-1. 한국여행 관심 계기_1순위  문1-1. 한국여행 관심 계기_2순위  \
# ...

# %%
raw['문10. 1인 1일 지출경비(상하위 1% 대체, 61일 이상 결측)'].unique()
# Out:
# array([451.66666667, 272.935     , 177.65      , ...,  52.8605    ,
#        151.03      ,  84.61538462])

# %%
df['문10. 1인 1일 지출경비(상하위 1% 대체, 61일 이상 결측)'].unique()
# Out:
# array([3, 2, 4, 1], dtype=int64)

# %%
df[df['문10. 1인 1일 지출경비(상하위 1% 대체, 61일 이상 결측)'].isna()]
# Out:
# Empty DataFrame
# Columns: [아이디, 성별, 연령별, 한국 방문횟수(카테고리), 문1-1. 한국여행 관심 계기_1, 문3-1. 고려한 관광활동_1, 문3-2. 고려한 관광인프라_1, 문10. 1인 1일 지출경비(상하위 1% 대체, 61일 이상 결측), 문9-3. 총 체재기간_61일 이상 결측, 숙박시설_그룹, 여행동반자_그룹, 방문 지역 수, 식비_비율, 국내 교통비_비율, 체험/활동비_비율, 뷰티/의료비_비율, 여행 서비스비_비율, 숙박비_비율, 쇼핑비_비율, 기타 비용_비율, 여행 패턴]
# Index: []
#
# [0 rows x 21 columns]

# %%
sorted(raw['문9-3. 총 체재기간'], reverse=True)
# Out:
# [91,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
#  90,
# ...

# %% [markdown]
# 90일 까지도 여행으로 볼 수 있지 않을까...?

# %%
raw.filter(like='문10. 1인')
# Out:
#        문10. 1인 지출경비(상하위 1% 대체)  문10. 1인 지출경비(상하위 1% 대체, 카테고리)  \
# 0                     2710.000                              3
# 1                     1364.675                              2
# 2                     1065.900                              2
# 3                      922.680                              1
# 4                     1647.300                              2
# ...                        ...                            ...
# 16211                  562.930                              1
# 16212                  335.520                              1
# 16213                 2677.350                              3
# 16214                  755.150                              1
# 16215                 2200.000                              3
#
#        문10. 1인 1일 지출경비(상하위 1% 대체, 61일 이상 결측)  \
# 0                                 451.666667
# 1                                 272.935000
# 2                                 177.650000
# ...

# %% [markdown]
# 아 근데 '1인 1일 지출경비' 칼럼은 61일 이상 결측이 아닌 칼럼이 없음.
#
# 그냥 결측값은 제거하겠음

# %%
cols = ['아이디', '문10. 1인 1일 지출경비(상하위 1% 대체, 61일 이상 결측)', '문9-3. 총 체재기간_61일 이상 결측']

# %%
df.drop(columns=['문10. 1인 1일 지출경비(상하위 1% 대체, 61일 이상 결측)', '문9-3. 총 체재기간_61일 이상 결측'], inplace=True)
df.shape
# Out:
# (10164, 19)

# %%
df = pd.merge(left=df, right=raw[cols], on='아이디', how='inner')
df.shape
# Out:
# (10164, 21)

# %%
df.columns
# Out:
# Index(['아이디', '성별', '연령별', '한국 방문횟수(카테고리)', '문1-1. 한국여행 관심 계기_1',
#        '문3-1. 고려한 관광활동_1', '문3-2. 고려한 관광인프라_1', '숙박시설_그룹', '여행동반자_그룹',
#        '방문 지역 수', '식비_비율', '국내 교통비_비율', '체험/활동비_비율', '뷰티/의료비_비율', '여행 서비스비_비율',
#        '숙박비_비율', '쇼핑비_비율', '기타 비용_비율', '여행 패턴',
#        '문10. 1인 1일 지출경비(상하위 1% 대체, 61일 이상 결측)', '문9-3. 총 체재기간_61일 이상 결측'],
#       dtype='object')

# %%
df.dropna(subset=['문10. 1인 1일 지출경비(상하위 1% 대체, 61일 이상 결측)', '문9-3. 총 체재기간_61일 이상 결측'], inplace=True)

# %%
df.shape
# Out:
# (10137, 21)

# %%
df.to_csv('C:/Users/sopi0/codes/korea-tour-recommender/data/2024_6차_전처리.csv', index=False)
