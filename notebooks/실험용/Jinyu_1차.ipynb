# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/sopi0/codes/korea-tour-recommender/data/1차_만족도조사.csv')
# Out:
# c:\Users\sopi0\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (40) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# pd.set_option('display.max_columns',None)
pd.reset_option('display.max_columns')
data
# Out:
#            아이디  한국 방문횟수(카테고리)  한국 방문횟수(재방문)  여행 형태  문1. 주요 방한 목적  \
# 0          6.0            4.0           5.0      1             1
# 1          7.0            4.0           5.0      1             2
# 2          8.0            2.0           5.0      1             5
# 3         10.0            1.0           NaN      1             3
# 4         12.0            1.0           NaN      1             1
# ...        ...            ...           ...    ...           ...
# 15776  21570.0            1.0           NaN      1             1
# 15777  21571.0            1.0           NaN      1             1
# 15778  21572.0            3.0           5.0      1             2
# 15779  21573.0            2.0           5.0      1             1
# 15780  21575.0            1.0           NaN      1             1
#
#        문1-1. 한국여행 관심 계기_1순위  문1-1. 한국여행 관심 계기_2순위  문1-1. 한국여행 관심 계기_3순위  \
# 0                       2.0                   3.0                   4.0
# ...

# %%
data.describe()
# Out:
#                 아이디  한국 방문횟수(카테고리)  한국 방문횟수(재방문)         여행 형태  문1. 주요 방한 목적  \
# count  15781.000000   15781.000000        8055.0  15781.000000  15781.000000
# mean   11222.086496       2.065142           5.0      1.246436      1.709271
# std     6147.872160       1.221092           0.0      0.625737      1.014100
# min        6.000000       1.000000           5.0      1.000000      1.000000
# 25%     5769.000000       1.000000           5.0      1.000000      1.000000
# 50%    11561.000000       2.000000           5.0      1.000000      1.000000
# 75%    16598.000000       3.000000           5.0      1.000000      2.000000
# max    21575.000000       4.000000           5.0      3.000000      5.000000
#
#        문1-1. 한국여행 관심 계기_1순위  문1-1. 한국여행 관심 계기_2순위  문1-1. 한국여행 관심 계기_3순위  \
# count          11838.000000           8692.000000           6689.000000
# mean               4.486231              5.781868              6.303184
# ...

# %%
# col = ['한국 방문횟수(카테고리)', '여행 형태', '문1. 주요 방한 목적', '월별', '분기별',
#        '국가별', '성별', '연령별']
# fig, ax = plt.subplots(3, 3, figsize=(15,15))
# for i in range(8):
#     sns.countplot(data=data, x=col[i], ax=ax[i][i%3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3ad0b2672cbf> in <module>
#       3 fig, ax = plt.subplots(3, 3, figsize=(15,15))
#       4 for i in range(8):
# ----> 5     sns.countplot(data=data, x=col[i], ax=ax[i][i%3])
#
# NameError: name 'data' is not defined

# %%
col = ['한국 방문횟수(카테고리)', '여행 형태', '문1. 주요 방한 목적', '월별', '분기별',
       '국가별', '성별', '연령별']

fig, ax = plt.subplots(3, 3, figsize=(15,15))
ax = ax.flatten()  # 2D → 1D

for i in range(len(col)):
    sns.countplot(data=data, x=col[i], ax=ax[i])

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-44c1e8e2f75c> in <module>
#       6
#       7 for i in range(len(col)):
# ----> 8     sns.countplot(data=data, x=col[i], ax=ax[i])
#       9
#      10 plt.tight_layout()
#
# NameError: name 'data' is not defined
